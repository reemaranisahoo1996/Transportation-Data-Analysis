# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\reema\Downloads\UI_assignments\Trip_gen_attract.csv')
df.head(20)
# Out:
#     Neighbourhood  Trp_Gen_Work  Total_Trips_generated  Trip_attr_work  \
# 0           10101          3439                  45485           14162
# 1           10102          6545                  51476            9311
# 2           10203          2552                  19968            4617
# 3           10204          2773                  20856            5947
# 4           10205          3273                  20968            4068
# 5           10306          9097                  66508            9779
# 6           10407          3550                  20079            2191
# 7           10408          9208                  46373            5007
# 8           10509          9985                  50699            3521
# 9           10612          9042                  45097            3755
# 10          10613          4937                  20745            1721
# 11          10714          5547                  37164            2973
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Neighbourhood            258 non-null    int64
#  1   Trp_Gen_Work             258 non-null    int64
#  2   Total_Trips_generated    258 non-null    int64
#  3   Trip_attr_work           258 non-null    int64
#  4   Trip_attracted           258 non-null    int64
#  5   Pop_m                    258 non-null    int64
#  6   Pop_f                    258 non-null    int64
#  7   HH                       258 non-null    int64
#  8   Busi_emp                 258 non-null    int64
#  9   Com_emp                  258 non-null    int64
#  10  Other_emp                258 non-null    int64
#  11  Ar_agri                  258 non-null    float64
#  12  Ar_industry              258 non-null    float64
#  13  Ar_park                  258 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Neighbourhood              0
# Trp_Gen_Work               0
# Total_Trips_generated      0
# Trip_attr_work             0
# Trip_attracted             0
# Pop_m                      0
# Pop_f                      0
# HH                         0
# Busi_emp                   0
# Com_emp                    0
# Other_emp                  0
# Ar_agri                    0
# Ar_industry                0
# Ar_park                    0
# Ar_parking                 0
# Ar_transport               0
# Ar_com_other               0
# Ar_Busi                    0
# Ar_com                     0
# Ar_religion                0
# Ar_puagency                0
# Ar_institute               0
# Ar_resi                    0
# Ar_vplot                   0
# Ar_water                   0
# Ar_forest                  0
# Ar_roads                   0
# Fl_Ar_busi                 0
# Fl_Ar_puagency             0
# Fl_Ar_resi                 0
# Fl_Ar_com                  0
# Fl_Ar_ins                  0
# ...

# %%
df.describe()
# Out:
#        Neighbourhood  Trp_Gen_Work  Total_Trips_generated  Trip_attr_work  \
# count     258.000000    258.000000             258.000000      258.000000
# mean    87250.635659   5284.430233           32488.922481     6243.356589
# std     45300.272618   2913.815758           16398.284410     5560.418490
# min     10101.000000      0.000000               0.000000        0.000000
# 25%     50303.250000   3439.000000           20925.250000     2738.000000
# 50%     90458.000000   5020.000000           31008.000000     4773.000000
# 75%    120716.750000   7460.250000           42961.250000     7804.250000
# max    160513.000000  15365.000000          132738.000000    43657.000000
#
#        Trip_attracted         Pop_m         Pop_f            HH      Busi_emp  \
# count      258.000000    258.000000    258.000000    258.000000    258.000000
# mean     34582.073643   4145.565891   4302.585271   3510.655039   2462.201550
# ...

# %%
df.columns
# Out:
# Index(['Neighbourhood', 'Trp_Gen_Work', 'Total_Trips_generated',
#        'Trip_attr_work', 'Trip_attracted', 'Pop_m', 'Pop_f', 'HH', 'Busi_emp',
#        'Com_emp', 'Other_emp', 'Ar_agri', 'Ar_industry', 'Ar_park',
#        'Ar_parking', 'Ar_transport', 'Ar_com_other', 'Ar_Busi', 'Ar_com',
#        'Ar_religion', 'Ar_puagency', 'Ar_institute', 'Ar_resi', 'Ar_vplot',
#        'Ar_water', 'Ar_forest', 'Ar_roads', 'Fl_Ar_busi', 'Fl_Ar_puagency',
#        'Fl_Ar_resi', 'Fl_Ar_com', 'Fl_Ar_ins', 'Fl_Ar_rest', 'Fl_Ar_hotels',
#        'Fl_Ar_am_1', 'Fl_Ar_am_2', 'Fl_Ar_ind', 'Fl_Ar_tran', 'Fl_Ar_aff',
#        'Transit_station_dist(m)'],
#       dtype='object')

# %%
corr=df.corr()
corr
# Out:
#                          Neighbourhood  Trp_Gen_Work  Total_Trips_generated  \
# Neighbourhood                 1.000000      0.170362              -0.024674
# Trp_Gen_Work                  0.170362      1.000000               0.690887
# Total_Trips_generated        -0.024674      0.690887               1.000000
# Trip_attr_work               -0.226825     -0.079924               0.562154
# Trip_attracted               -0.043856      0.648602               0.997389
# Pop_m                         0.171045      0.926106               0.646837
# Pop_f                         0.171029      0.926106               0.646837
# HH                            0.065062      0.886267               0.663726
# Busi_emp                     -0.283044     -0.191548               0.389045
# Com_emp                      -0.246392     -0.147303               0.438123
# Other_emp                    -0.051812     -0.029936               0.199357
# ...

# %%
correlated=corr['Total_Trips_generated'][corr['Total_Trips_generated']>0.5]

# %%
correlated.index
# Out:
# Index(['Trp_Gen_Work', 'Total_Trips_generated', 'Trip_attr_work',
#        'Trip_attracted', 'Pop_m', 'Pop_f', 'HH', 'Ar_com', 'Ar_resi',
#        'Fl_Ar_resi', 'Fl_Ar_com'],
#       dtype='object')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
X=df.loc[:, ['Trp_Gen_Work', 'Total_Trips_generated', 'Trip_attr_work',
       'Trip_attracted', 'Pop_m', 'Pop_f', 'HH', 'Ar_com', 'Ar_resi',
       'Fl_Ar_resi', 'Fl_Ar_com']]
X
# Out:
#      Trp_Gen_Work  Total_Trips_generated  Trip_attr_work  Trip_attracted  \
# 0            3439                  45485           14162           50142
# 1            6545                  51476            9311           54467
# 2            2552                  19968            4617           21502
# 3            2773                  20856            5947           22710
# 4            3273                  20968            4068           22212
# ..            ...                    ...             ...             ...
# 253          2052                  10371            1017           10868
# 254          3328                  16750             860           17187
# 255          6102                  39327            4773           41100
# 256          9042                  51976            6651           54215
# 257          7821                  40271            1487           41005
#
#      Pop_m  Pop_f    HH    Ar_com    Ar_resi  Fl_Ar_resi  Fl_Ar_com
# ...

# %%
sns.pairplot(data=X)

# %%
y=df['Total_Trips_generated']
y
# Out:
# 0      45485
# 1      51476
# 2      19968
# 3      20856
# 4      20968
#        ...
# 253    10371
# 254    16750
# 255    39327
# 256    51976
# 257    40271
# Name: Total_Trips_generated, Length: 258, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 101)

# %%
scaler = StandardScaler()

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model=LinearRegression()

# %%
result=linear_model.fit(X_train,y_train)

# %%
result.coef_
# Out:
# array([ 1.62281089e-14,  1.00000000e+00, -5.68324348e-17, -7.43320112e-15,
#        -1.96747971e-12,  1.91456532e-12,  1.98699257e-15, -7.12418606e-17,
#        -2.60301474e-16, -1.78825120e-17,  3.01784704e-16])

# %%
result.intercept_
# Out:
# -6.912159733474255e-11

# %%
result.score(X_train, y_train)
# Out:
# 1.0

# %%
result.score(X_test, y_test)
# Out:
# 1.0

# %%
coeffecients=pd.DataFrame(result.coef_, index=X.columns, columns=['Coef'])

# %%
coeffecients
# Out:
#                                Coef
# Trp_Gen_Work           1.622811e-14
# Total_Trips_generated  1.000000e+00
# Trip_attr_work        -5.683243e-17
# Trip_attracted        -7.433201e-15
# Pop_m                 -1.967480e-12
# Pop_f                  1.914565e-12
# HH                     1.986993e-15
# Ar_com                -7.124186e-17
# Ar_resi               -2.603015e-16
# Fl_Ar_resi            -1.788251e-17
# Fl_Ar_com              3.017847e-16

# %%
y_pred=linear_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score

# %%
mse=mean_squared_error(y_test, y_pred)
mse
# Out:
# 3.846073293457466e-21

# %%
rmse=np.sqrt(mse)

# %%
accuracy=1-rmse
accuracy
# Out:
# 0.9999999999379833
